# %%
import pandas as pd
import numpy as np
import seaborn as sns
link = "https://raw.githubusercontent.com/WildCodeSchool/data-training-resources/main/quests//weather2019.csv"
df_weather = pd.read_csv(link)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import seaborn as sns
#       4 link = "https://raw.githubusercontent.com/WildCodeSchool/data-training-resources/main/quests//weather2019.csv"
#       5 df_weather = pd.read_csv(link)
#
# File c:\Users\Gaetan Rigaut\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\__init__.py:2, in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File c:\Users\Gaetan Rigaut\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\rcmod.py:3, in <module>
#       1 """Control plot style and scaling using the matplotlib rcParams interface."""
#       2 import functools
# ...

# %% [markdown]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import seaborn as sns
#       4 link = "https://raw.githubusercontent.com/WildCodeSchool/data-training-resources/main/quests//weather2019.csv"
#       5 df_weather = pd.read_csv(link)
#
# File c:\Users\Gaetan Rigaut\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\__init__.py:2, in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File c:\Users\Gaetan Rigaut\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\rcmod.py:3, in <module>
#       1 """Control plot style and scaling using the matplotlib rcParams interface."""
#       2 import functools
# ----> 3 import matplotlib as mpl
#       4 from cycler import cycler
#       5 from . import palettes
#
# File c:\Users\Gaetan Rigaut\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py:188, in <module>
#     184 from packaging.version import parse as parse_version
#     186 # cbook must import matplotlib only within function
# ...
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: DLL load failed while importing _path: Le module spécifié est introuvable.
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...

# %% [markdown]
# You have now a DataFrame with lots of weather data

# %%
df_weather.head()
# Out:
#          DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0  2019-01-01                  9                  4                 10
# 1  2019-01-02                  8                  5                 18
# 2  2019-01-03                  6                  0                 18
# 3  2019-01-04                  5                 -1                 15
# 4  2019-01-05                  6                 -1                  8
#
#    TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                      4                   7                      8
# 1                      7                   7                      5
# 2                      0                   4                      3
# 3                     -1                   4                      3
# 4                     -1                   4                      3
#
#    PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# ...

# %%
df=df_weather.drop(["DATE","OPINION"], axis=1)

# %%
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <module>
# ----> 1 sns.heatmap(df.corr())
#
# NameError: name 'sns' is not defined
